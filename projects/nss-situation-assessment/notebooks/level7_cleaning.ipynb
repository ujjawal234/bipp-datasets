# %%
from pathlib import Path
import pandas as pd

# %%
dir_path = Path.cwd()
raw_data_path = Path.joinpath(dir_path, "data", "raw")
interim_data_path = Path.joinpath(dir_path, "data", "interim")
ext_data_path = Path.joinpath(dir_path, "data", "external")

# %%
df = pd.read_stata(Path.joinpath(raw_data_path, "level7.dta"))
df.columns
# Out:
# Index(['common_id', 'State', 'Sector', 'District', 'Centre_code_Round',
#        'FSU_Serial_No', 'Round', 'Schedule', 'Sample', 'NSS_Region', 'Stratum',
#        'Sub_Stratum', 'Sub_Round', 'FOD_Sub_Region', 'Second_stage_stratum_no',
#        'Sample_hhld_No', 'Visit_number', 'Level', 'Filler', 'Sl_no',
#        'Crop_code', 'other_disp_sale_value', 'all_disp_quant_sold',
#        'all_disp_sale_value', 'Rate_Rs', 'value_of_pre_harvest_sale',
#        'value_of_harvested_produce', 'value_of_by_products', 'total_value',
#        'Blank', 'NSC', 'Multiplier', 'w'],
#       dtype='object')

# %%
df.drop(['Centre_code_Round',
       'FSU_Serial_No', 'Round', 'Schedule', 'Sample', 'NSS_Region', 'Stratum',
       'Sub_Stratum', 'Sub_Round', 'FOD_Sub_Region', 'Second_stage_stratum_no',
       'Sample_hhld_No', 'Visit_number', 'Blank', 'Level', 'Filler', 'NSC'], axis = 1, inplace = True)

# %%
var_names = [x.lower() for x in df.columns]
df.columns = var_names

# %%
if df["common_id"].is_unique:
    print("Common ID is unique for Level 7")
else:
    print("Common ID not unique for Level 7")
# Out:
# Common ID not unique for Level 7

# %%
df
# Out:
#         common_id  state  sector  district  sl_no  crop_code  \
# 0        72227201      1       1         5      1      104.0
# 1        72227201      1       1         5      9     9999.0
# 2        72227202      1       1         5      1      104.0
# 3        72227202      1       1         5      9     9999.0
# 4        72227301      1       1         5      1      104.0
# ...           ...    ...     ...       ...    ...        ...
# 109915   70112501     36       1        31      4      104.0
# 109916   70112501     36       1        31      9     9999.0
# 109917   70112502     36       1        31      1     1101.0
# 109918   70112502     36       1        31      2      101.0
# 109919   70112502     36       1        31      9     9999.0
#
#         other_disp_sale_value  all_disp_quant_sold  all_disp_sale_value  \
# 0                         NaN                 50.0                900.0
# 1                         NaN                  NaN                  NaN
# 2                         NaN                100.0               1800.0
# 3                         NaN                  NaN                  NaN
# 4                         NaN                150.0               2700.0
# ...                       ...                  ...                  ...
# 109915                    NaN               7500.0             131250.0
# 109916                    NaN                  NaN                  NaN
# 109917                    NaN               1640.0              85280.0
# 109918                    NaN               2150.0              26450.0
# 109919                    NaN                  NaN                  NaN
#
#         rate_rs  value_of_pre_harvest_sale  value_of_harvested_produce  \
# 0          18.0                        NaN                      7200.0
# 1           NaN                        NaN                      7200.0
# 2          18.0                        NaN                      4500.0
# 3           NaN                        NaN                      4500.0
# 4          18.0                        NaN                      3600.0
# ...         ...                        ...                         ...
# 109915     17.5                        NaN                    131250.0
# 109916      NaN                   300000.0                    427025.0
# 109917     52.0                        NaN                     85280.0
# 109918     12.3                        NaN                     35055.0
# 109919      NaN                        NaN                    120335.0
#
#         value_of_by_products  total_value  multiplier       w
# 0                     3000.0      10200.0      170500  1705.0
# 1                     3000.0      10200.0      170500  1705.0
# 2                     1800.0       6300.0      170500  1705.0
# 3                     1800.0       6300.0      170500  1705.0
# 4                     2200.0       5800.0      403000  4030.0
# ...                      ...          ...         ...     ...
# 109915                   NaN     131250.0      100500  1005.0
# 109916                4500.0     731525.0      100500  1005.0
# 109917                   NaN      85280.0      100500  1005.0
# 109918                2000.0      37055.0      100500  1005.0
# 109919                2000.0     122335.0      100500  1005.0
#
# [109920 rows x 16 columns]

# %%
labels = pd.read_csv(Path.joinpath(ext_data_path, "crop_code_labels.csv"))

# %%
crop_list = list(labels['crop'])
code_list = list(labels['code'])

# %%
crop_labels = {}

# %%
for i in range(0, len(code_list)):
  c = crop_list[i].split(".")
  cr = c[0].split(" ")
  crop_labels[code_list[i]] = cr[0]

# %%
df.columns
# Out:
# Index(['common_id', 'state', 'sector', 'district', 'sl_no', 'crop_code',
#        'other_disp_sale_value', 'all_disp_quant_sold', 'all_disp_sale_value',
#        'rate_rs', 'value_of_pre_harvest_sale', 'value_of_harvested_produce',
#        'value_of_by_products', 'total_value', 'multiplier', 'w'],
#       dtype='object')

# %%
df['crop_code'] = df['crop_code'].map(crop_labels)

# %%
df
# Out:
#         common_id  state  sector  district  sl_no crop_code  \
# 0        72227201      1       1         5      1     maize
# 1        72227201      1       1         5      9       NaN
# 2        72227202      1       1         5      1     maize
# 3        72227202      1       1         5      9       NaN
# 4        72227301      1       1         5      1     maize
# ...           ...    ...     ...       ...    ...       ...
# 109915   70112501     36       1        31      4     maize
# 109916   70112501     36       1        31      9       NaN
# 109917   70112502     36       1        31      1    cotton
# 109918   70112502     36       1        31      2     paddy
# 109919   70112502     36       1        31      9       NaN
#
#         other_disp_sale_value  all_disp_quant_sold  all_disp_sale_value  \
# 0                         NaN                 50.0                900.0
# 1                         NaN                  NaN                  NaN
# 2                         NaN                100.0               1800.0
# 3                         NaN                  NaN                  NaN
# 4                         NaN                150.0               2700.0
# ...                       ...                  ...                  ...
# 109915                    NaN               7500.0             131250.0
# 109916                    NaN                  NaN                  NaN
# 109917                    NaN               1640.0              85280.0
# 109918                    NaN               2150.0              26450.0
# 109919                    NaN                  NaN                  NaN
#
#         rate_rs  value_of_pre_harvest_sale  value_of_harvested_produce  \
# 0          18.0                        NaN                      7200.0
# 1           NaN                        NaN                      7200.0
# 2          18.0                        NaN                      4500.0
# 3           NaN                        NaN                      4500.0
# 4          18.0                        NaN                      3600.0
# ...         ...                        ...                         ...
# 109915     17.5                        NaN                    131250.0
# 109916      NaN                   300000.0                    427025.0
# 109917     52.0                        NaN                     85280.0
# 109918     12.3                        NaN                     35055.0
# 109919      NaN                        NaN                    120335.0
#
#         value_of_by_products  total_value  multiplier       w
# 0                     3000.0      10200.0      170500  1705.0
# 1                     3000.0      10200.0      170500  1705.0
# 2                     1800.0       6300.0      170500  1705.0
# 3                     1800.0       6300.0      170500  1705.0
# 4                     2200.0       5800.0      403000  4030.0
# ...                      ...          ...         ...     ...
# 109915                   NaN     131250.0      100500  1005.0
# 109916                4500.0     731525.0      100500  1005.0
# 109917                   NaN      85280.0      100500  1005.0
# 109918                2000.0      37055.0      100500  1005.0
# 109919                2000.0     122335.0      100500  1005.0
#
# [109920 rows x 16 columns]

# %%
csv_path = Path.joinpath(interim_data_path, "level7.csv")
df.to_csv(csv_path, index=False)
