# %%
from pathlib import Path
import pandas as pd

# %%
dir_path = Path.cwd()
raw_data_path = Path.joinpath(dir_path, "data", "raw")
interim_data_path = Path.joinpath(dir_path, "data", "interim")
processed_data_path = Path.joinpath(dir_path, "data", "processed")

# %%
df = pd.read_csv(Path.joinpath(interim_data_path, "cattle.csv"))
#District-wise cattle population in 2019

# %%
df.columns
# Out:
# Index(['state_name', 'district_name', 'breed_type_name',
#        'upto_one_and_half_years_male', 'used_for_breeding_only_male',
#        'used_for_agriculture_only_male', 'agriculture_and_breeding_male',
#        'bullock_cart_farm_operations_male', 'others_male', 'total_male',
#        'under_one_ year_female', 'one_to_two_and_half_years_female',
#        'in_milk_female', 'dry_female', 'not_calved_once_female',
#        'others_female', 'total_female', 'total'],
#       dtype='object')

# %%
male = df[['state_name', 'district_name', 'breed_type_name',
       'upto_one_and_half_years_male', 'used_for_breeding_only_male',
       'used_for_agriculture_only_male', 'agriculture_and_breeding_male',
       'bullock_cart_farm_operations_male', 'others_male', 'total_male', 'total']]
female = df[['state_name', 'district_name', 'breed_type_name', 'under_one_ year_female', 'one_to_two_and_half_years_female',
       'in_milk_female', 'dry_female', 'not_calved_once_female',
       'others_female', 'total_female', 'total']]

# %%
male
# Out:
#                        state_name             district_name   breed_type_name  \
# 0     Andaman And Nicobar Islands                  Nicobars            Exotic
# 1     Andaman And Nicobar Islands                  Nicobars  Indigenous(Desi)
# 2     Andaman And Nicobar Islands  North And Middle Andaman            Exotic
# 3     Andaman And Nicobar Islands  North And Middle Andaman  Indigenous(Desi)
# 4     Andaman And Nicobar Islands            South Andamans            Exotic
# ...                           ...                       ...               ...
# 1383                  West Bengal                     Nadia  Indigenous(Desi)
# 1384                  West Bengal         PASCHIM BARDHAMAN            Exotic
# 1385                  West Bengal         PASCHIM BARDHAMAN  Indigenous(Desi)
# 1386                  West Bengal                   Purulia            Exotic
# 1387                  West Bengal                   Purulia  Indigenous(Desi)
#
#       upto_one_and_half_years_male  used_for_breeding_only_male  \
# 0                                0                            0
# 1                              169                          109
# 2                              562                           22
# 3                              983                          177
# 4                              824                          228
# ...                            ...                          ...
# 1383                         52708                         4652
# 1384                          1906                          205
# 1385                         18863                         1262
# 1386                          1372                          275
# 1387                         76292                        14435
#
#       used_for_agriculture_only_male  agriculture_and_breeding_male  \
# 0                                  0                              0
# 1                                 45                             75
# 2                                 35                             39
# 3                               2033                           1104
# 4                                 20                             57
# ...                              ...                            ...
# 1383                           20767                           2712
# 1384                             326                             86
# 1385                           18644                           1209
# 1386                             728                            224
# 1387                          366207                          11247
#
#       bullock_cart_farm_operations_male  others_male  total_male   total
# 0                                     0            0           0      40
# 1                                    10           58         466    1964
# 2                                     2           12         672    6571
# 3                                    19           55        4371    9147
# 4                                    15           22        1166    8908
# ...                                 ...          ...         ...     ...
# 1383                               1628         2629       85096  451704
# 1384                                924          185        3632   45128
# 1385                               2571         1181       43730  228509
# 1386                                335          236        3170   18075
# 1387                              23886         9535      501602  897199
#
# [1388 rows x 11 columns]

# %%
male['female'] = '0'
female['female'] = '1'
# Out:
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
male = male.rename(columns={'upto_one_and_half_years_male':'upto_one_and_half_years',
                'used_for_breeding_only_male':'used_for_breeding_only',
                'used_for_agriculture_only_male': 'used_for_agriculture_only',
                'agriculture_and_breeding_male': 'agriculture_and_breeding',
                'bullock_cart_farm_operations_male': 'bullock_cart_farm_operations',
                'others_male': 'others'})

# %%
cols = male.columns.to_list()

# %%
cols = ['state_name', 'district_name', 'female', 'breed_type_name',
       'upto_one_and_half_years', 'used_for_breeding_only',
       'used_for_agriculture_only', 'agriculture_and_breeding',
       'bullock_cart_farm_operations', 'others', 'total_male',
       'total']

# %%
male = male[cols]

# %%
female.columns
# Out:
# Index(['state_name', 'district_name', 'breed_type_name',
#        'under_one_ year_female', 'one_to_two_and_half_years_female',
#        'in_milk_female', 'dry_female', 'not_calved_once_female',
#        'others_female', 'total_female', 'total', 'female'],
#       dtype='object')

# %%
female = female.rename(columns={'under_one_year_female':'under_one_year',
                                'one_to_two_and_half_years_female':'one_to_two_and_half_years',
                                'in_milk_female':'in_milk',
                                'dry_female':'dry',
                                'not_calved_once_female':'not_calved_once',
                                'others_female':'others'})

# %%
df  = pd.concat([male, female], axis = 0)

# %%
cols
# Out:
# ['state_name',
#  'district_name',
#  'female',
#  'breed_type_name',
#  'upto_one_and_half_years',
#  'used_for_breeding_only',
#  'used_for_agriculture_only',
#  'agriculture_and_breeding',
#  'bullock_cart_farm_operations',
#  'others',
#  'total_male',
#  'total']

# %%
cols = df.columns.to_list()

# %%
cols = ['state_name',
 'district_name',
 'female',
 'breed_type_name',
 'upto_one_and_half_years',
 'used_for_breeding_only',
 'used_for_agriculture_only',
 'agriculture_and_breeding',
 'bullock_cart_farm_operations',
 'under_one_ year_female',
 'one_to_two_and_half_years',
 'in_milk',
 'dry',
 'not_calved_once',
 'others',
 'total_male',
 'total_female',
 'total']

# %%
df = df[cols]

# %%
df1 = df.sort_values(by = 'state_name')

# %%
df1
# Out:
#                        state_name             district_name female  \
# 0     Andaman And Nicobar Islands                  Nicobars      0
# 0     Andaman And Nicobar Islands                  Nicobars      1
# 5     Andaman And Nicobar Islands            South Andamans      1
# 3     Andaman And Nicobar Islands  North And Middle Andaman      1
# 2     Andaman And Nicobar Islands  North And Middle Andaman      1
# ...                           ...                       ...    ...
# 1368                  West Bengal                  Jhargram      0
# 1367                  West Bengal                Jalpaiguri      0
# 1366                  West Bengal                Jalpaiguri      0
# 1375                  West Bengal                    Maldah      0
# 1387                  West Bengal                   Purulia      1
#
#        breed_type_name  upto_one_and_half_years  used_for_breeding_only  \
# 0               Exotic                      0.0                     0.0
# 0               Exotic                      NaN                     NaN
# 5     Indigenous(Desi)                      NaN                     NaN
# 3     Indigenous(Desi)                      NaN                     NaN
# 2               Exotic                      NaN                     NaN
# ...                ...                      ...                     ...
# 1368            Exotic                   2625.0                  1263.0
# 1367  Indigenous(Desi)                  66951.0                  7736.0
# 1366            Exotic                   4075.0                   390.0
# 1375  Indigenous(Desi)                  89169.0                 18347.0
# 1387  Indigenous(Desi)                      NaN                     NaN
#
#       used_for_agriculture_only  agriculture_and_breeding  \
# 0                           0.0                       0.0
# 0                           NaN                       NaN
# 5                           NaN                       NaN
# 3                           NaN                       NaN
# 2                           NaN                       NaN
# ...                         ...                       ...
# 1368                     1913.0                     342.0
# 1367                    72630.0                    9134.0
# 1366                     1222.0                     341.0
# 1375                    79395.0                   12635.0
# 1387                        NaN                       NaN
#
#       bullock_cart_farm_operations  under_one_ year_female  \
# 0                              0.0                     NaN
# 0                              NaN                    14.0
# 5                              NaN                  1947.0
# 3                              NaN                  1419.0
# 2                              NaN                  1434.0
# ...                            ...                     ...
# 1368                         221.0                     NaN
# 1367                        1983.0                     NaN
# 1366                         212.0                     NaN
# 1375                        8096.0                     NaN
# 1387                           NaN                 95903.0
#
#       one_to_two_and_half_years   in_milk      dry  not_calved_once  others  \
# 0                           NaN       NaN      NaN              NaN       0
# 0                          10.0      15.0      1.0              0.0       0
# 5                        1518.0    2214.0   1550.0            251.0      26
# 3                         806.0    1508.0    905.0             81.0      57
# 2                         843.0    2130.0   1219.0            206.0      67
# ...                         ...       ...      ...              ...     ...
# 1368                        NaN       NaN      NaN              NaN     306
# 1367                        NaN       NaN      NaN              NaN    5995
# 1366                        NaN       NaN      NaN              NaN     566
# 1375                        NaN       NaN      NaN              NaN    7737
# 1387                    83206.0  124112.0  63365.0          20918.0    8093
#
#       total_male  total_female   total
# 0            0.0           NaN      40
# 0            NaN          40.0      40
# 5            NaN        7506.0    9808
# 3            NaN        4776.0    9147
# 2            NaN        5899.0    6571
# ...          ...           ...     ...
# 1368      6670.0           NaN   41274
# 1367    164429.0           NaN  670061
# 1366      6806.0           NaN   57531
# 1375    215379.0           NaN  917496
# 1387         NaN      395597.0  897199
#
# [2776 rows x 18 columns]

# %%
df1.to_csv(Path.joinpath(processed_data_path, "cattle.csv"), index=False)
