# %%
from pathlib import Path
import pandas as pd

# %%
dir_path = Path.cwd()
raw_data_path = Path.joinpath(dir_path, "data", "raw")
interim_data_path = Path.joinpath(dir_path, "data", "interim")
processed_data_path = Path.joinpath(dir_path, "data", "processed")

# %%
male = pd.read_csv(Path.joinpath(interim_data_path, "goat_male.csv"))
#District-wise male goat population in 2019

# %%
female = pd.read_csv(Path.joinpath(interim_data_path, "goat_female.csv"))
#District-wise female goat population in 2019

# %%
male['female'] = '0'
female['female'] = '1'

# %%
female['state_name'] = male['state_name']
female['district_name'] = male['district_name']
male['total'] = female['total']

# %%
male
# Out:
#                       state_name             district_name  under_one_year  \
# 0    Andaman And Nicobar Islands                  Nicobars            1806
# 1    Andaman And Nicobar Islands  North And Middle Andaman            4396
# 2    Andaman And Nicobar Islands            South Andamans            4857
# 3                 Andhra Pradesh                 Anantapur           79377
# 4                 Andhra Pradesh                  Chittoor           57888
# ..                           ...                       ...             ...
# 693                  West Bengal            Medinipur West          137166
# 694                  West Bengal               Murshidabad          355590
# 695                  West Bengal                     Nadia          190343
# 696                  West Bengal         PASCHIM BARDHAMAN           38998
# 697                  West Bengal                   Purulia          171104
#
#      one_year_and_above  total_male female    total
# 0                  1282        3088      0     8884
# 1                  4253        8649      0    27664
# 2                  4607        9464      0    28213
# 3                 86493      165870      0   884186
# 4                 55083      112971      0   535063
# ..                  ...         ...    ...      ...
# 693              166252      303418      0   872869
# 694              274486      630076      0  1751276
# 695              154253      344596      0   924339
# 696               38158       77156      0   256143
# 697              249213      420317      0   966681
#
# [698 rows x 7 columns]

# %%
df = pd.concat([male, female], axis = 0)

# %%
df
# Out:
#                       state_name             district_name  under_one_year  \
# 0    Andaman And Nicobar Islands                  Nicobars            1806
# 1    Andaman And Nicobar Islands  North And Middle Andaman            4396
# 2    Andaman And Nicobar Islands            South Andamans            4857
# 3                 Andhra Pradesh                 Anantapur           79377
# 4                 Andhra Pradesh                  Chittoor           57888
# ..                           ...                       ...             ...
# 693                  West Bengal            Medinipur West          220112
# 694                  West Bengal               Murshidabad          526724
# 695                  West Bengal                     Nadia          247443
# 696                  West Bengal         PASCHIM BARDHAMAN           71991
# 697                  West Bengal                   Purulia          193466
#
#      one_year_and_above  total_male female    total   in_milk       dry  \
# 0                1282.0      3088.0      0     8884       NaN       NaN
# 1                4253.0      8649.0      0    27664       NaN       NaN
# 2                4607.0      9464.0      0    28213       NaN       NaN
# 3               86493.0    165870.0      0   884186       NaN       NaN
# 4               55083.0    112971.0      0   535063       NaN       NaN
# ..                  ...         ...    ...      ...       ...       ...
# 693                 NaN         NaN      1   872869  169931.0  134255.0
# 694                 NaN         NaN      1  1751276  359569.0  179048.0
# 695                 NaN         NaN      1   924339  183501.0  113675.0
# 696                 NaN         NaN      1   256143   61207.0   33024.0
# 697                 NaN         NaN      1   966681  178602.0  125512.0
#
#      not_calved_once  total_female
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN           NaN
# 3                NaN           NaN
# 4                NaN           NaN
# ..               ...           ...
# 693          45153.0      569451.0
# 694          55859.0     1121200.0
# 695          35124.0      579743.0
# 696          12765.0      178987.0
# 697          48784.0      546364.0
#
# [1396 rows x 11 columns]

# %%
cols = df.columns.tolist()

# %%
cols
# Out:
# ['state_name',
#  'district_name',
#  'under_one_year',
#  'one_year_and_above',
#  'total_male',
#  'female',
#  'total',
#  'in_milk',
#  'dry',
#  'not_calved_once',
#  'total_female']

# %%
cols =['state_name',
 'district_name',
 'female',
 'under_one_year',
 'one_year_and_above',
 'in_milk',
 'dry',
 'not_calved_once',
 'total_male',
 'total_female',
 'total']

# %%
df = df[cols]

# %%
df1 = df.sort_values(by = 'state_name')

# %%
df1
# Out:
#                       state_name             district_name female  \
# 0    Andaman And Nicobar Islands                  Nicobars      0
# 0    Andaman And Nicobar Islands                  Nicobars      1
# 2    Andaman And Nicobar Islands            South Andamans      1
# 1    Andaman And Nicobar Islands  North And Middle Andaman      1
# 1    Andaman And Nicobar Islands  North And Middle Andaman      0
# ..                           ...                       ...    ...
# 693                  West Bengal            Medinipur West      0
# 694                  West Bengal               Murshidabad      0
# 695                  West Bengal                     Nadia      0
# 696                  West Bengal         PASCHIM BARDHAMAN      1
# 697                  West Bengal                   Purulia      1
#
#      under_one_year  one_year_and_above   in_milk       dry  not_calved_once  \
# 0              1806              1282.0       NaN       NaN              NaN
# 0              2144                 NaN    2162.0    1294.0            196.0
# 2              6208                 NaN    6450.0    4876.0           1215.0
# 1              6671                 NaN    5815.0    5675.0            854.0
# 1              4396              4253.0       NaN       NaN              NaN
# ..              ...                 ...       ...       ...              ...
# 693          137166            166252.0       NaN       NaN              NaN
# 694          355590            274486.0       NaN       NaN              NaN
# 695          190343            154253.0       NaN       NaN              NaN
# 696           71991                 NaN   61207.0   33024.0          12765.0
# 697          193466                 NaN  178602.0  125512.0          48784.0
#
#      total_male  total_female    total
# 0        3088.0           NaN     8884
# 0           NaN        5796.0     8884
# 2           NaN       18749.0    28213
# 1           NaN       19015.0    27664
# 1        8649.0           NaN    27664
# ..          ...           ...      ...
# 693    303418.0           NaN   872869
# 694    630076.0           NaN  1751276
# 695    344596.0           NaN   924339
# 696         NaN      178987.0   256143
# 697         NaN      546364.0   966681
#
# [1396 rows x 11 columns]

# %%
df1.to_csv(Path.joinpath(processed_data_path, "goat.csv"), index=False)
