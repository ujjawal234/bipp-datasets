# %%
from pathlib import Path
import pandas as pd
from fuzzywuzzy import process
# Out:
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
dir_path = Path.cwd()
raw_data_path = Path.joinpath(dir_path, "data", "raw")
interim_data_path = Path.joinpath(dir_path, "data", "interim")
processed_data_path = Path.joinpath(dir_path, "data", "processed")
ext_data_path = Path.joinpath(dir_path, "data", "external")

# %%
lgd = pd.read_csv(Path.joinpath(ext_data_path, "lgd_district.csv"))

# %%
lgd.drop(["St_Cs2011_code","St_Cs2001_code","Dt_Cs2011_code", "Dt_Cs2001_code"], axis=1, inplace=True)

# %%
lgd = lgd.rename(
    columns={
        "State Name(In English)": "state",
        "District Name(In English)": "district",
    }
)

# %%
lgd["state_dist"] = ""
for i in range(0, 734):
    lgd["state_dist"][i] = lgd["state"][i].rstrip() + lgd["district"][i]
# Out:
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
lgd
# Out:
#      St_LGD_code                                              state  \
# 0             35     ANDAMAN AND NICOBAR ISLANDS
# 1             35     ANDAMAN AND NICOBAR ISLANDS
# 2             35     ANDAMAN AND NICOBAR ISLANDS
# 3             28  ANDHRA PRADESH                                ...
# 4             28  ANDHRA PRADESH                                ...
# ..           ...                                                ...
# 729           19  WEST BENGAL                                   ...
# 730           19  WEST BENGAL                                   ...
# 731           19  WEST BENGAL                                   ...
# 732           19  WEST BENGAL                                   ...
# 733           19  WEST BENGAL                                   ...
#
#      Dt_LGD_code                  district  \
# 0            603                  NICOBARS
# 1            632  NORTH AND MIDDLE ANDAMAN
# 2            602            SOUTH ANDAMANS
# 3            502                 ANANTAPUR
# 4            503                  CHITTOOR
# ..           ...                       ...
# 729          319               MURSHIDABAD
# 730          320                     NADIA
# 731          704         PASCHIM BARDHAMAN
# 732          306           PURBA BARDHAMAN
# 733          321                   PURULIA
#
#                                             state_dist
# 0                  ANDAMAN AND NICOBAR ISLANDSNICOBARS
# 1    ANDAMAN AND NICOBAR ISLANDSNORTH AND MIDDLE AN...
# 2            ANDAMAN AND NICOBAR ISLANDSSOUTH ANDAMANS
# 3                              ANDHRA PRADESHANANTAPUR
# 4                               ANDHRA PRADESHCHITTOOR
# ..                                                 ...
# 729                             WEST BENGALMURSHIDABAD
# 730                                   WEST BENGALNADIA
# 731                       WEST BENGALPASCHIM BARDHAMAN
# 732                         WEST BENGALPURBA BARDHAMAN
# 733                                 WEST BENGALPURULIA
#
# [734 rows x 5 columns]

# %%
cattle = pd.read_csv(Path.joinpath(processed_data_path, "cattle.csv"))
buffalo = pd.read_csv(Path.joinpath(processed_data_path, "buffalo.csv"))
goat = pd.read_csv(Path.joinpath(processed_data_path, "goat.csv"))
pig = pd.read_csv(Path.joinpath(processed_data_path, "pig.csv"))
sheep = pd.read_csv(Path.joinpath(processed_data_path, "sheep.csv"))

# %%
cattle["state_name"] = cattle["state_name"].str.upper()
cattle["district_name"] = cattle["district_name"].str.upper()
pig["state_name"] = pig["state_name"].str.upper()
pig["district_name"] = pig["district_name"].str.upper()
buffalo["state_name"] = buffalo["state_name"].str.upper()
buffalo["district_name"] = buffalo["district_name"].str.upper()
sheep["state_name"] = sheep["state_name"].str.upper()
sheep["district_name"] = sheep["district_name"].str.upper()
goat["state_name"] = goat["state_name"].str.upper()
goat["district_name"] = goat["district_name"].str.upper()

# %%
cattle['state_dist']  = cattle['state_name'] + cattle['district_name']
buffalo['state_dist']  = buffalo['state_name'] + buffalo['district_name']
pig['state_dist']  = pig['state_name'] + pig['district_name']
goat['state_dist']  = goat['state_name'] + goat['district_name']
sheep['state_dist']  = sheep['state_name'] + sheep['district_name']

# %%
c1 = pd.merge(
            cattle,
            lgd,
            how="outer",
            left_on="state_dist",
            right_on="state_dist",
            validate="m:1",
            indicator=True,
            suffixes=["_DATA", "_LGD"],
        )

# %%
c1
# Out:
#                        state_name   district_name  female   breed_type_name  \
# 0     ANDAMAN AND NICOBAR ISLANDS        NICOBARS     0.0            Exotic
# 1     ANDAMAN AND NICOBAR ISLANDS        NICOBARS     1.0            Exotic
# 2     ANDAMAN AND NICOBAR ISLANDS        NICOBARS     1.0  Indigenous(Desi)
# 3     ANDAMAN AND NICOBAR ISLANDS        NICOBARS     0.0  Indigenous(Desi)
# 4     ANDAMAN AND NICOBAR ISLANDS  SOUTH ANDAMANS     1.0  Indigenous(Desi)
# ...                           ...             ...     ...               ...
# 2850                          NaN             NaN     NaN               NaN
# 2851                          NaN             NaN     NaN               NaN
# 2852                          NaN             NaN     NaN               NaN
# 2853                          NaN             NaN     NaN               NaN
# 2854                          NaN             NaN     NaN               NaN
#
#       upto_one_and_half_years  used_for_breeding_only  \
# 0                         0.0                     0.0
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                       169.0                   109.0
# 4                         NaN                     NaN
# ...                       ...                     ...
# 2850                      NaN                     NaN
# 2851                      NaN                     NaN
# 2852                      NaN                     NaN
# 2853                      NaN                     NaN
# 2854                      NaN                     NaN
#
#       used_for_agriculture_only  agriculture_and_breeding  \
# 0                           0.0                       0.0
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                          45.0                      75.0
# 4                           NaN                       NaN
# ...                         ...                       ...
# 2850                        NaN                       NaN
# 2851                        NaN                       NaN
# 2852                        NaN                       NaN
# 2853                        NaN                       NaN
# 2854                        NaN                       NaN
#
#       bullock_cart_farm_operations  under_one_ year_female  ...  others  \
# 0                              0.0                     NaN  ...     0.0
# 1                              NaN                    14.0  ...     0.0
# 2                              NaN                   337.0  ...    22.0
# 3                             10.0                     NaN  ...    58.0
# 4                              NaN                  1947.0  ...    26.0
# ...                            ...                     ...  ...     ...
# 2850                           NaN                     NaN  ...     NaN
# 2851                           NaN                     NaN  ...     NaN
# 2852                           NaN                     NaN  ...     NaN
# 2853                           NaN                     NaN  ...     NaN
# 2854                           NaN                     NaN  ...     NaN
#
#       total_male  total_female   total  \
# 0            0.0           NaN    40.0
# 1            NaN          40.0    40.0
# 2            NaN        1498.0  1964.0
# 3          466.0           NaN  1964.0
# 4            NaN        7506.0  9808.0
# ...          ...           ...     ...
# 2850         NaN           NaN     NaN
# 2851         NaN           NaN     NaN
# 2852         NaN           NaN     NaN
# 2853         NaN           NaN     NaN
# 2854         NaN           NaN     NaN
#
#                                      state_dist  St_LGD_code  \
# 0           ANDAMAN AND NICOBAR ISLANDSNICOBARS         35.0
# 1           ANDAMAN AND NICOBAR ISLANDSNICOBARS         35.0
# 2           ANDAMAN AND NICOBAR ISLANDSNICOBARS         35.0
# 3           ANDAMAN AND NICOBAR ISLANDSNICOBARS         35.0
# 4     ANDAMAN AND NICOBAR ISLANDSSOUTH ANDAMANS         35.0
# ...                                         ...          ...
# 2850                    UTTARAKHANDRUDRA PRAYAG          5.0
# 2851                UTTARAKHANDUDAM SINGH NAGAR          5.0
# 2852                     UTTARAKHANDUTTAR KASHI          5.0
# 2853                      WEST BENGALAlipurduar         19.0
# 2854                        WEST BENGALJhargram         19.0
#
#                                                   state  Dt_LGD_code  \
# 0        ANDAMAN AND NICOBAR ISLANDS                           603.0
# 1        ANDAMAN AND NICOBAR ISLANDS                           603.0
# 2        ANDAMAN AND NICOBAR ISLANDS                           603.0
# 3        ANDAMAN AND NICOBAR ISLANDS                           603.0
# 4        ANDAMAN AND NICOBAR ISLANDS                           602.0
# ...                                                 ...          ...
# 2850                                        UTTARAKHAND         54.0
# 2851                                        UTTARAKHAND         56.0
# 2852                                        UTTARAKHAND         57.0
# 2853  WEST BENGAL                                   ...        664.0
# 2854  WEST BENGAL                                   ...        703.0
#
#               district      _merge
# 0             NICOBARS        both
# 1             NICOBARS        both
# 2             NICOBARS        both
# 3             NICOBARS        both
# 4       SOUTH ANDAMANS        both
# ...                ...         ...
# 2850      RUDRA PRAYAG  right_only
# 2851  UDAM SINGH NAGAR  right_only
# 2852       UTTAR KASHI  right_only
# 2853        Alipurduar  right_only
# 2854          Jhargram  right_only
#
# [2855 rows x 24 columns]

# %%
not_lgd_mapped = c1[(c1["_merge"] == "left_only")][
            [
                "state_name",
                "district_name",
                "state_dist",
            ]
        ]

# %%
not_lgd_mapped = not_lgd_mapped.drop_duplicates(subset="state_dist")

# %%
len(not_lgd_mapped)
# Out:
# 45

# %%
result = [
            process.extractOne(i, lgd["state_dist"])
            for i in not_lgd_mapped["state_dist"]
        ]
result = pd.DataFrame(result, columns=["match", "score", "id"])
result.drop("id", axis=1, inplace=True)

# %%
result
# Out:
#                                                 match  score
# 0                                         ASSAMKAMRUP     95
# 1                        ASSAMSOUTH SALMARA MANCACHAR     90
# 2                                       ASSAMMARIGAON     92
# 3                               CHHATTISGARHKABIRDHAM     95
# 4   THE DADRA AND NAGAR HAVELI AND DAMAN AND DIUDAMAN     90
# 5     THE DADRA AND NAGAR HAVELI AND DAMAN AND DIUDIU     90
# 6                                    GUJARATMahisagar    100
# 7                             JAMMU AND KASHMIRBudgam     96
# 8                            JAMMU AND KASHMIRRAJOURI     96
# 9                             KARNATAKACHIKKAMAGALURU     93
# 10                          KARNATAKADAKSHINA KANNADA     96
# 11                           KARNATAKACHIKKABALLAPURA     93
# 12                           KARNATAKACHAMARAJANAGARA     98
# 13                                 KARNATAKABAGALKOTE     97
# 14                                  KARNATAKATUMAKURU     94
# 15                                KARNATAKASHIVAMOGGA     91
# 16                            KARNATAKAUTTARA KANNADA     95
# 17                                       MIZORAMSAIHA     92
# 18                    PUNJABShahid Bhagat Singh Nagar    100
# 19                                   PUNJABTarn Taran    100
# 20                                  PUNJABS.A.S Nagar    100
# 21                                 TAMIL NADUAriyalur    100
# 22                    TELANGANAKUMURAM BHEEM ASIFABAD     95
# 23                               TELANGANARANGA REDDY     92
# 24                                    TELANGANANirmal    100
# 25                                  TELANGANAJagitial    100
# 26                              TELANGANAMAHABUBNAGAR     98
# 27                    TELANGANAKUMURAM BHEEM ASIFABAD    100
# 28                    TELANGANAKUMURAM BHEEM ASIFABAD     90
# 29                                     TRIPURAUnakoti    100
# 30                                TRIPURAWest Tripura    100
# 31                                      TRIPURADhalai    100
# 32                                  TRIPURASepahijala    100
# 33                                      TRIPURAGomati    100
# 34                                      TRIPURAKhowai    100
# 35                               TRIPURANorth Tripura    100
# 36                               TRIPURASouth Tripura    100
# 37                                UTTAR PRADESHAmethi    100
# 38                             UTTAR PRADESHFIROZABAD     93
# 39                               UTTAR PRADESHKasganj    100
# 40                        UTTARAKHANDUDAM SINGH NAGAR     98
# 41                            UTTARAKHANDRUDRA PRAYAG     98
# 42                             UTTARAKHANDUTTAR KASHI     98
# 43                              WEST BENGALAlipurduar    100
# 44                                WEST BENGALJhargram    100

# %%
not_lgd_proxy_df = (
                pd.DataFrame(not_lgd_mapped["state_dist"], index=None)
                .reset_index()
                .drop("index", axis=1)
        )

# %%
mapper_df = pd.concat(
            [not_lgd_proxy_df, result],
            axis=1,
            ignore_index=True,
            names=["original", "match", "score"],
        )

# %%
mapper_df = mapper_df[mapper_df[2] >= 90]

# %%
mapper_dict = dict(zip(mapper_df[0], mapper_df[1]))
cattle["state_dist"] = cattle["state_dist"].replace(mapper_dict)

# %%
c1 = pd.merge(
            cattle,
            lgd,
            how="outer",
            left_on="state_dist",
            right_on="state_dist",
            validate="m:1",
            indicator=True,
            suffixes=["_DATA", "_LGD"],
        )

# %%
c1["_merge"].value_counts()
# Out:
# both          2776
# right_only      38
# left_only        0
# Name: _merge, dtype: int64

# %%
not_lgd_mapped = c1[(c1["_merge"] == "left_only")][
            [
                "state_name",
                "district_name",
                "state_dist",
            ]
        ]
not_lgd_mapped = not_lgd_mapped.drop_duplicates(subset="state_dist")

# %%
len(not_lgd_mapped)
# Out:
# 0

# %%
result = [
            process.extractOne(i, lgd["state_dist"])
            for i in not_lgd_mapped["state_dist"]
        ]
result = pd.DataFrame(result, columns=["match", "score", "id"])
result.drop("id", axis=1, inplace=True)

# %%
not_lgd_proxy_df = (
                pd.DataFrame(not_lgd_mapped["state_dist"], index=None)
                .reset_index()
                .drop("index", axis=1)
        )

# %%
mapper_df = pd.concat(
            [not_lgd_proxy_df, result],
            axis=1,
            ignore_index=True,
            names=["original", "match", "score"],
        )

# %%
mapper_df = mapper_df[mapper_df[2] >= 90]

# %%
mapper_dict = dict(zip(mapper_df[0], mapper_df[1]))
cattle["state_dist"] = cattle["state_dist"].replace(mapper_dict)

# %%
c1 = pd.merge(
            cattle,
            lgd,
            how="outer",
            left_on="state_dist",
            right_on="state_dist",
            validate="m:1",
            indicator=True,
            suffixes=["_DATA", "_LGD"],
        )

# %%
c1["_merge"].value_counts()
# Out:
# both          2776
# right_only      38
# left_only        0
# Name: _merge, dtype: int64

# %%
not_lgd_mapped = c1[(c1["_merge"] == "left_only")][
            [
                "state_name",
                "district_name",
                "state_dist",
            ]
        ]
not_lgd_mapped = not_lgd_mapped.drop_duplicates(subset="state_dist")

# %%
len(not_lgd_mapped)
# Out:
# 0

# %%
not_lgd_mapped.to_csv("cattle_unmapped.csv")

# %%
for i in range(0, 2776):
    if (cattle['district_name'][i].upper() == 'SORAIDEU'):
        cattle['district_name'][i] = 'CHARAIDEO'
    if (cattle['district_name'][i].upper() == 'SIBSAGAR'):
        cattle['district_name'][i] = 'SIVASAGAR'
    if (cattle['district_name'][i].upper() == 'MEWAT'):
        cattle['district_name'][i] = 'NUH'
    if (cattle['district_name'][i].upper() == 'KARGIL'):
        cattle['state_name'][i] = 'LADAKH'
    if (cattle['district_name'][i].upper() == 'LEH LADAKH'):
        cattle['state_name'][i] = 'LADAKH'
    if (cattle['district_name'][i].upper() == 'DADRA AND NAGAR HAVELI'):
        cattle['state_name'][i] = 'THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU'
    if (cattle['district_name'][i].upper() == 'GULBARGA'):
        cattle['district_name'][i] = 'KALABURAGI'
    if (cattle['district_name'][i].upper() == 'MYSORE'):
        cattle['district_name'][i] = 'MYSURU'
    if (cattle['district_name'][i].upper() == 'BANGALORE RURAL'):
        cattle['district_name'][i] = 'BENGALURU RURAL'
    if (cattle['district_name'][i].upper() == 'SORAIDEU'):
        cattle['district_name'][i] = 'CHARAIDEO'
    if (cattle['district_name'][i].upper() == 'BELGAUM'):
        cattle['district_name'][i] = 'BELAGAVI'
    if (cattle['district_name'][i].upper() == 'BELLARY'):
        cattle['district_name'][i] = 'BALLARI'
    if (cattle['district_name'][i].upper() in 'NAWANSHAHR (SBS NAGAR)'):
        cattle['district_name'][i] = 'SHAHID BHAGAT SINGH NAGAR'
    if (cattle['district_name'][i].upper() == 'MUKTSAR'):
        cattle['district_name'][i] = 'SRI MUKTSAR SAHIB'
    if (cattle['district_name'][i].upper() == 'ALLAHABAD'):
        cattle['district_name'][i] = 'PRAYAGRAJ'
    if (cattle['district_name'][i].upper() == 'SANT RAVIDAS NAGAR'):
        cattle['district_name'][i] = 'BHADOHI'
    if (cattle['district_name'][i].upper() == 'BARDHAMAN'):
        cattle['district_name'][i] = 'PURBA BARDHAMAN'
    if (cattle['district_name'][i].upper() == 'BIJAPUR') and (cattle['state_name'][i].upper() == 'KARNATAKA'):
        cattle['district_name'][i] = 'VIJAYAPURA'
# Out:
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\gohal\Desktop\Coding\bipp-datasets\.venv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
cattle.to_csv(Path.joinpath(processed_data_path, "cattle.csv"), index=False)

# %%
c2 = c1[c1["_merge"] == "both"]

# %%
c2 = c2.drop(['_merge','state', 'district'], axis = 1)

# %%
c2.columns.to_list()
# Out:
# ['state_name',
#  'district_name',
#  'female',
#  'breed_type_name',
#  'upto_one_and_half_years',
#  'used_for_breeding_only',
#  'used_for_agriculture_only',
#  'agriculture_and_breeding',
#  'bullock_cart_farm_operations',
#  'under_one_ year_female',
#  'one_to_two_and_half_years',
#  'in_milk',
#  'dry',
#  'not_calved_once',
#  'others',
#  'total_male',
#  'total_female',
#  'total',
#  'state_dist',
#  'St_LGD_code',
#  'Dt_LGD_code']

# %%
l = ['state_name',
 'district_name',
'state_dist',
 'St_LGD_code',
 'Dt_LGD_code',
 'female',
 'breed_type_name',
 'upto_one_and_half_years',
 'used_for_breeding_only',
 'used_for_agriculture_only',
 'agriculture_and_breeding',
 'bullock_cart_farm_operations',
 'under_one_ year_female',
 'one_to_two_and_half_years',
 'in_milk',
 'dry',
 'not_calved_once',
 'others',
 'total_male',
 'total_female',
 'total']

# %%
c2 = c2[l]

# %%
c2.to_csv(Path.joinpath(processed_data_path, "cattle_lgd.csv"), index=False)

# %%
c2.shape
# Out:
# (2776, 21)

# %%
cattle.shape
# Out:
# (2776, 19)

# %%
cattle = pd.read_csv(Path.joinpath(processed_data_path, "cattle_lgd.csv"))

# %%
cattle.drop(['state_dist'], axis = 1, inplace = True)
cattle.rename(columns={'St_LGD_code':'state_lgd_code', 'Dt_LGD_code':'district_lgd_code'}, inplace = True)

# %%
cattle.to_csv(Path.joinpath(processed_data_path, "cattle_lgd.csv"), index=False)

# %%
cattle
# Out:
#                        state_name   district_name  state_lgd_code  \
# 0     ANDAMAN AND NICOBAR ISLANDS        NICOBARS              35
# 1     ANDAMAN AND NICOBAR ISLANDS        NICOBARS              35
# 2     ANDAMAN AND NICOBAR ISLANDS        NICOBARS              35
# 3     ANDAMAN AND NICOBAR ISLANDS        NICOBARS              35
# 4     ANDAMAN AND NICOBAR ISLANDS  SOUTH ANDAMANS              35
# ...                           ...             ...             ...
# 2771                  WEST BENGAL  DINAJPUR UTTAR              19
# 2772                  WEST BENGAL         PURULIA              19
# 2773                  WEST BENGAL         PURULIA              19
# 2774                  WEST BENGAL         PURULIA              19
# 2775                  WEST BENGAL         PURULIA              19
#
#       district_lgd_code  female   breed_type_name  upto_one_and_half_years  \
# 0                   603     0.0            Exotic                      0.0
# 1                   603     1.0            Exotic                      NaN
# 2                   603     1.0  Indigenous(Desi)                      NaN
# 3                   603     0.0  Indigenous(Desi)                    169.0
# 4                   602     1.0  Indigenous(Desi)                      NaN
# ...                 ...     ...               ...                      ...
# 2771                311     0.0            Exotic                   3285.0
# 2772                321     0.0  Indigenous(Desi)                  76292.0
# 2773                321     0.0            Exotic                   1372.0
# 2774                321     1.0            Exotic                      NaN
# 2775                321     1.0  Indigenous(Desi)                      NaN
#
#       used_for_breeding_only  used_for_agriculture_only  \
# 0                        0.0                        0.0
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                      109.0                       45.0
# 4                        NaN                        NaN
# ...                      ...                        ...
# 2771                   300.0                      800.0
# 2772                 14435.0                   366207.0
# 2773                   275.0                      728.0
# 2774                     NaN                        NaN
# 2775                     NaN                        NaN
#
#       agriculture_and_breeding  bullock_cart_farm_operations  \
# 0                          0.0                           0.0
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                         75.0                          10.0
# 4                          NaN                           NaN
# ...                        ...                           ...
# 2771                     109.0                          96.0
# 2772                   11247.0                       23886.0
# 2773                     224.0                         335.0
# 2774                       NaN                           NaN
# 2775                       NaN                           NaN
#
#       under_one_ year_female  one_to_two_and_half_years   in_milk      dry  \
# 0                        NaN                        NaN       NaN      NaN
# 1                       14.0                       10.0      15.0      1.0
# 2                      337.0                      362.0     458.0    255.0
# 3                        NaN                        NaN       NaN      NaN
# 4                     1947.0                     1518.0    2214.0   1550.0
# ...                      ...                        ...       ...      ...
# 2771                     NaN                        NaN       NaN      NaN
# 2772                     NaN                        NaN       NaN      NaN
# 2773                     NaN                        NaN       NaN      NaN
# 2774                  3713.0                     2597.0    6145.0   1461.0
# 2775                 95903.0                    83206.0  124112.0  63365.0
#
#       not_calved_once  others  total_male  total_female     total
# 0                 NaN     0.0         0.0           NaN      40.0
# 1                 0.0     0.0         NaN          40.0      40.0
# 2                64.0    22.0         NaN        1498.0    1964.0
# 3                 NaN    58.0       466.0           NaN    1964.0
# 4               251.0    26.0         NaN        7506.0    9808.0
# ...               ...     ...         ...           ...       ...
# 2771              NaN   364.0      4954.0           NaN   67854.0
# 2772              NaN  9535.0    501602.0           NaN  897199.0
# 2773              NaN   236.0      3170.0           NaN   18075.0
# 2774            647.0   342.0         NaN       14905.0   18075.0
# 2775          20918.0  8093.0         NaN      395597.0  897199.0
#
# [2776 rows x 20 columns]
