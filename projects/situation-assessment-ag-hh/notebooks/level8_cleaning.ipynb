# %%
import pandas as pd
from pathlib import Path

# %%
dir_path = Path.cwd()
raw_data_path = Path.joinpath(dir_path, "data", "raw")
interim_data_path = Path.joinpath(dir_path, "data", "interim")
ext_data_path = Path.joinpath(dir_path, "data", "external")

# %%
df = pd.read_stata(Path.joinpath(raw_data_path, "level8.dta"))
df.columns
# Out:
# Index(['common_id', 'State', 'Sector', 'District', 'Centre_code_Round',
#        'FSU_Serial_No', 'Round', 'Schedule', 'Sample', 'NSS_Region', 'Stratum',
#        'Sub_Stratum', 'Sub_Round', 'FOD_Sub_Region', 'Second_stage_stratum_no',
#        'Sample_hhld_No', 'Visit_number', 'Level', 'Filler', 'Sl_no',
#        'Sl_no_crop', 'Crop_code', 'Inputs_from_where_procur',
#        'Inputs_qual_adeq_code', 'Inputs_paid_out_exp', 'Inputs_imputed_exp',
#        'Blank', 'NSC', 'Multiplier', 'w'],
#       dtype='object')

# %%
df.drop(['Centre_code_Round',
       'FSU_Serial_No', 'Round', 'Schedule', 'Sample', 'NSS_Region', 'Stratum',
       'Sub_Stratum', 'Sub_Round', 'FOD_Sub_Region', 'Second_stage_stratum_no',
       'Sample_hhld_No', 'Visit_number', 'Blank', 'Level', 'Filler', 'NSC'], axis = 1, inplace = True)

# %%
var_names = [x.lower() for x in df.columns]
df.columns = var_names

# %%
if df["common_id"].is_unique:
    print("Common ID is unique for Level 8")
else:
    print("Common ID not unique for Level 8")
# Out:
# Common ID not unique for Level 8

# %%
df
# Out:
#         common_id  state  sector  district  sl_no  sl_no_crop  crop_code  \
# 0        72227201      1       1         5      1         1.0      104.0
# 1        72227201      1       1         5      6         NaN        NaN
# 2        72227201      1       1         5      8         NaN        NaN
# 3        72227201      1       1         5     14         NaN        NaN
# 4        72227201      1       1         5     15         NaN        NaN
# ...           ...    ...     ...       ...    ...         ...        ...
# 340769   70112502     36       1        31     17         NaN        NaN
# 340770   70112502     36       1        31     18         NaN        NaN
# 340771   70112502     36       1        31     20         NaN        NaN
# 340772   70112502     36       1        31     21         NaN        NaN
# 340773   70112502     36       1        31     22         NaN        NaN
#
#         inputs_from_where_procur  inputs_qual_adeq_code  inputs_paid_out_exp  \
# 0                            1.0                    1.0                245.0
# 1                            1.0                    1.0                890.0
# 2                           10.0                    1.0                  NaN
# 3                            NaN                    NaN               1000.0
# 4                            NaN                    NaN               1200.0
# ...                          ...                    ...                  ...
# 340769                       NaN                    NaN              12000.0
# 340770                       NaN                    NaN              12990.0
# 340771                       NaN                    NaN              38000.0
# 340772                       NaN                    NaN               4500.0
# 340773                       NaN                    NaN             143490.0
#
#         inputs_imputed_exp  multiplier       w
# 0                      NaN      170500  1705.0
# 1                      NaN      170500  1705.0
# 2                   1000.0      170500  1705.0
# 3                    800.0      170500  1705.0
# 4                      NaN      170500  1705.0
# ...                    ...         ...     ...
# 340769                 NaN      100500  1005.0
# 340770                 NaN      100500  1005.0
# 340771                 NaN      100500  1005.0
# 340772               400.0      100500  1005.0
# 340773             11300.0      100500  1005.0
#
# [340774 rows x 13 columns]

# %%
labels = pd.read_csv(Path.joinpath(ext_data_path, "crop_code_labels.csv"))

# %%
crop_list = list(labels['crop'])
code_list = list(labels['code'])

# %%
crop_labels = {}
for i in range(0, len(code_list)):
  c = crop_list[i].split(".")
  cr = c[0].split(" ")
  crop_labels[float(code_list[i])] = cr[0]

# %%
print(crop_labels)
# Out:
# {1.0: 'Cereals', 101.0: 'paddy', 102.0: 'jowar', 103.0: 'bajra', 104.0: 'maize', 105.0: 'ragi', 106.0: 'wheat', 107.0: 'barley', 108.0: 'small', 188.0: 'other', 2.0: 'Pulses', 201.0: 'gram', 202.0: 'tur', 203.0: 'urad', 204.0: 'moong', 205.0: 'masur', 206.0: 'horse', 207.0: 'beans', 208.0: 'peas', 288.0: 'other', 4.0: 'Sugar', 401.0: 'sugarcane', 402.0: 'palmvriah', 488.0: 'other', 5.0: 'Condiments', 501.0: 'pepper', 502.0: 'chillies', 503.0: 'ginger', 504.0: 'turmeric', 505.0: 'cardamom', 506.0: 'cardamom', 507.0: 'betel', 508.0: 'garlic', 509.0: 'coriander', 510.0: 'tamarind', 511.0: 'cumin', 512.0: 'fennel', 513.0: 'nutmeg', 514.0: 'fenugreek', 515.0: 'cloves', 516.0: 'cinnamon', 517.0: 'cocoa', 518.0: 'kacholam', 519.0: 'betelvine', 588.0: 'Other', 6.0: 'Fruits', 601.0: 'mangoes', 602.0: 'orange', 603.0: 'mosambi', 604.0: 'lemon', 605.0: 'othercitrous', 606.0: 'banana', 607.0: 'table', 608.0: 'wine', 609.0: 'apple', 610.0: 'pear', 611.0: 'peaches', 612.0: 'plum', 613.0: 'kiwi', 614.0: 'chiku', 615.0: 'papaya', 616.0: 'guava', 617.0: 'almond', 618.0: 'walnut', 619.0: 'cashewnuts', 620.0: 'apricot', 621.0: 'jackfruit', 622.0: 'lichi', 623.0: 'pineapple', 624.0: 'watermelon', 625.0: 'musk', 626.0: 'bread', 627.0: 'ber', 628.0: 'bel', 629.0: 'mulberry', 630.0: 'aonla', 688.0: 'other', 7.0: 'Tuber', 701.0: 'potato', 702.0: 'tapioca', 703.0: 'sweet', 704.0: 'yam', 705.0: 'elephant', 706.0: 'colocasia/arum', 788.0: 'other', 8.0: 'Vegetables', 801.0: 'onion', 802.0: 'carrot', 803.0: 'radish', 804.0: 'beetroot', 805.0: 'turnip', 806.0: 'tomato', 807.0: 'spinach', 808.0: 'amaranths', 809.0: 'cabbage', 810.0: 'other', 811.0: 'brinjal', 812.0: 'peas', 813.0: 'lady’s', 814.0: 'cauliflower', 815.0: 'cucumber', 816.0: 'bottle', 817.0: 'pumpkin', 818.0: 'bitter', 819.0: 'other', 820.0: 'guar', 821.0: 'beans', 822.0: 'drumstick', 823.0: 'green', 888.0: 'other', 901.0: 'other', 10.0: 'Oilseeds', 1001.0: 'groundnut', 1002.0: 'castorseed', 1003.0: 'sesamum', 1004.0: 'rapeseed', 1005.0: 'linseed', 1006.0: 'coconut', 1007.0: 'sunflower', 1008.0: 'safflower', 1009.0: 'soyabean', 1010.0: 'nigerseed', 1011.0: 'oil', 1012.0: 'toria', 1088.0: 'other', 11.0: 'Fibres', 1101.0: 'cotton', 1102.0: 'jute', 1103.0: 'mesta', 1104.0: 'sunhemp', 1188.0: 'other', 12.0: 'Dyes', 1201.0: 'indigo', 1288.0: 'other', 13.0: 'Drugs', 1301.0: 'opium', 1302.0: 'tobacco', 1388.0: 'other', 14.0: 'Fodder', 1401.0: 'guar', 1402.0: 'oats', 1403.0: 'green', 1488.0: 'other', 15.0: 'Plantation', 1501.0: 'tea', 1502.0: 'coffee', 1503.0: 'rubber', 1588.0: 'other', 16.0: 'Flower', 1601.0: 'orchids', 1602.0: 'rose', 1603.0: 'gladiolus', 1604.0: 'carnation', 1605.0: 'marigold', 1688.0: 'other', 17.0: 'Medicinal', 1701.0: 'asgandh', 1702.0: 'isabgol', 1703.0: 'sena', 1704.0: 'moosli', 1788.0: 'other', 18.0: 'Aromatic', 1801.0: 'lemon', 1802.0: 'mint', 1803.0: 'menthol', 1804.0: 'eucalyptus', 1888.0: 'other', 19.0: 'Other', 1901.0: 'canes', 1902.0: 'bamboos', 1988.0: 'other'}

# %%
where_procure_labels = {1:'local market (incl. local traders)',2: 'APMC market', 3: 'input dealers', 4: 'cooperative', 5: 'Government agencies', 6: 'Farmer producer organisations (FPO)', 7: 'private processors', 8: 'contract farming sponsors/ companies', 10: 'own farm', 9: 'others'}
quality_labels = {1: 'good', 2: 'satisfactory', 3: 'poor', 4: 'dont know'}

# %%
df['input'] = df['sl_no']

# %%
input_labels = {1: 'seeds', 2: 'seeds', 3: 'seeds', 4: 'seeds', 5: 'seeds', 6: 'chemical fertilizers', 7: 'bio-fertilizers', 8:'manures', 9:'plant protection materials chemical', 10: 'plant protection materials bio-pesticides', 11: 'diesel', 12:'electricity', 13: 'irrigation', 14: 'labour human', 15: 'labour animal', 16: 'minor repair and maintenance of machinery and equipment used in crop production', 17: 'interest on loans utilised for the purpose of crop production', 18: 'cost of hiring of machinery and equipment for crop production', 19: 'cost of crop insurance', 20: 'lease rent for land used for crop production', 21: 'other expenses for crop production', 22: 'total'}

# %%
#for i in range(0, len((df[df['crop_code'].isnull()==0]['crop_code']))):
#    df[df['crop_code'].isnull()==0]['crop_code'][i] = int(df[df['crop_code'].isnull()==0]['crop_code'][i])

# %%
print(df[df['crop_code'].isnull()==0])
# Out:
#         common_id  state  sector  district  sl_no  sl_no_crop  crop_code  \
# 0        72227201      1       1         5      1         1.0      104.0
# 8        72227202      1       1         5      1         1.0      104.0
# 16       72227301      1       1         5      1         1.0      104.0
# 17       72227301      1       1         5      2         2.0     1488.0
# 24       72227302      1       1         5      1         1.0      104.0
# ...           ...    ...     ...       ...    ...         ...        ...
# 340743   70112501     36       1        31      2         2.0      101.0
# 340744   70112501     36       1        31      3         3.0     1804.0
# 340745   70112501     36       1        31      4         4.0      104.0
# 340758   70112502     36       1        31      1         1.0     1101.0
# 340759   70112502     36       1        31      2         2.0      101.0
#
#                   inputs_from_where_procur inputs_qual_adeq_code  \
# 0       local market (incl. local traders)                  good
# 8       local market (incl. local traders)                  good
# 16      local market (incl. local traders)                  good
# 17      local market (incl. local traders)          satisfactory
# 24      local market (incl. local traders)                  good
# ...                                    ...                   ...
# 340743                       input dealers                  good
# 340744                              others                  good
# 340745  local market (incl. local traders)                  good
# 340758  local market (incl. local traders)                  good
# 340759  local market (incl. local traders)                  good
#
#         inputs_paid_out_exp  inputs_imputed_exp  multiplier       w  input
# 0                     245.0                 NaN      170500  1705.0      1
# 8                     245.0                 NaN      170500  1705.0      1
# 16                   1650.0                 NaN      403000  4030.0      1
# 17                    650.0                 NaN      403000  4030.0      2
# 24                    340.0                 NaN      403000  4030.0      1
# ...                     ...                 ...         ...     ...    ...
# 340743               9800.0                 NaN      100500  1005.0      2
# 340744                  NaN                 NaN      100500  1005.0      3
# 340745               7460.0                 NaN      100500  1005.0      4
# 340758               6400.0                 NaN      100500  1005.0      1
# 340759               2100.0                 NaN      100500  1005.0      2
#
# [67673 rows x 14 columns]

# %%
df['input'] = df['input'].map(input_labels)
df['inputs_from_where_procur'] = df['inputs_from_where_procur'].map(where_procure_labels)
df['inputs_qual_adeq_code'] = df['inputs_qual_adeq_code'].map(quality_labels)
df['crop_code'] = df['crop_code'].map(crop_labels)

# %%
df
# Out:
#         common_id  state  sector  district  sl_no  sl_no_crop crop_code  \
# 0        72227201      1       1         5      1         1.0     maize
# 1        72227201      1       1         5      6         NaN       NaN
# 2        72227201      1       1         5      8         NaN       NaN
# 3        72227201      1       1         5     14         NaN       NaN
# 4        72227201      1       1         5     15         NaN       NaN
# ...           ...    ...     ...       ...    ...         ...       ...
# 340769   70112502     36       1        31     17         NaN       NaN
# 340770   70112502     36       1        31     18         NaN       NaN
# 340771   70112502     36       1        31     20         NaN       NaN
# 340772   70112502     36       1        31     21         NaN       NaN
# 340773   70112502     36       1        31     22         NaN       NaN
#
#        inputs_from_where_procur inputs_qual_adeq_code  inputs_paid_out_exp  \
# 0                           NaN                   NaN                245.0
# 1                           NaN                   NaN                890.0
# 2                           NaN                   NaN                  NaN
# 3                           NaN                   NaN               1000.0
# 4                           NaN                   NaN               1200.0
# ...                         ...                   ...                  ...
# 340769                      NaN                   NaN              12000.0
# 340770                      NaN                   NaN              12990.0
# 340771                      NaN                   NaN              38000.0
# 340772                      NaN                   NaN               4500.0
# 340773                      NaN                   NaN             143490.0
#
#         inputs_imputed_exp  multiplier       w input
# 0                      NaN      170500  1705.0   NaN
# 1                      NaN      170500  1705.0   NaN
# 2                   1000.0      170500  1705.0   NaN
# 3                    800.0      170500  1705.0   NaN
# 4                      NaN      170500  1705.0   NaN
# ...                    ...         ...     ...   ...
# 340769                 NaN      100500  1005.0   NaN
# 340770                 NaN      100500  1005.0   NaN
# 340771                 NaN      100500  1005.0   NaN
# 340772               400.0      100500  1005.0   NaN
# 340773             11300.0      100500  1005.0   NaN
#
# [340774 rows x 14 columns]

# %%
csv_path = Path.joinpath(interim_data_path, "level8.csv")
df.to_csv(csv_path, index=False)
