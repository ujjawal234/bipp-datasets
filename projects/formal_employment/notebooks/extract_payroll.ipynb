# %%
# %matplotlib widget

# %%
import camelot
from pathlib import Path
import pandas as pd
import numpy as np

# %%
# source_reports = {"march_2022", "december_2022"}
src_pdf_filename = "december_2022"
payroll_report_pdf = Path.cwd().parent / "data" / "raw" / "payroll_reports" / f"{src_pdf_filename}.pdf"

# %%
raw_tables = camelot.read_pdf(str(payroll_report_pdf), pages="all", flavor="lattice")
# Out:
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (559.18, 561.67504) does not lie in column range (45.11043823685006, 558.8473518742444)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (559.3, 561.79504) does not lie in column range (45.11043823685006, 559.0873035066506)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (559.3, 561.79504) does not lie in column range (45.11067256461608, 559.0873035066506)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (559.3, 561.90352) does not lie in column range (45.11067256461608, 558.9673276904475)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (395.47, 397.96504000000004) does not lie in column range (45.11043823685006, 395.20033857315605)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (399.67, 402.16504000000003) does not lie in column range (45.11043823685006, 399.2795163240629)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (410.35, 412.84504000000004) does not lie in column range (45.34992121372431, 410.07733978234586)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (414.31, 416.80504) does not lie in column range (45.11043823685006, 414.1565175332528)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (415.27, 417.76504) does not lie in column range (45.11067256461608, 414.87637243047163)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (417.67, 420.16504000000003) does not lie in column range (45.35038986925635, 417.2758887545345)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/camelot/utils.py:740: UserWarning:   (559.06, 561.55504) does not lie in column range (45.11043823685006, 558.8473518742444)
#   warnings.warn(

# %%
tables = list(map(lambda t: t.df.copy(), raw_tables))

# %%
def basic_cleaning(df: pd.DataFrame):
    df = df.dropna(how="all", axis=1)
    df = df.replace(r"[\r\n\s]+", " ", regex=True) \
        .replace('-', '', regex=True) \
        .replace("", np.nan)
    print("Load Table:", df.shape, "->", df.shape)
    return df

# %%
cln_tables = list(map(basic_cleaning, tables))
# Out:
# Load Table: (9, 16) -> (9, 16)
# Load Table: (9, 16) -> (9, 16)
# Load Table: (9, 16) -> (9, 16)
# Load Table: (9, 16) -> (9, 16)
# Load Table: (9, 16) -> (9, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (10, 16) -> (10, 16)
# Load Table: (9, 9) -> (9, 9)
# Load Table: (9, 9) -> (9, 9)
# Load Table: (9, 9) -> (9, 9)
# Load Table: (9, 9) -> (9, 9)
# Load Table: (9, 9) -> (9, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 9) -> (10, 9)
# Load Table: (10, 18) -> (10, 18)
# Load Table: (10, 18) -> (10, 18)
# Load Table: (10, 18) -> (10, 18)
# Load Table: (10, 18) -> (10, 18)
# Load Table: (10, 18) -> (10, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)
# Load Table: (11, 18) -> (11, 18)

# %%
def is_monthly(df: pd.DataFrame):
    return df.iloc[0, :].str.contains("\w{3,9}\s\d{4}", regex=True).any()

# %%
def is_epf(df: pd.DataFrame):
    return df.iloc[:, 1].str.lower().str.contains('new EPF subscriber', na=False, case=False).any()

# %%
monthly_epf_tables = list(filter(is_monthly, filter(is_epf, cln_tables)))

# %%
def parse_date_head(df: pd.DataFrame) -> pd.Series:
    return pd.to_datetime(
        df.iloc[:, 0],
        format="%B %Y",
        errors="coerce"
    ).dropna()

# %%
def strip_month_headline(df: pd.DataFrame):
    date_df = parse_date_head(df)
    date_row_idx = date_df.index[0]
    return df.iloc[date_row_idx + 1:].reset_index(drop=True)

# %%
def exclude_totals_row(df: pd.DataFrame):
    return df[~df.iloc[:, 0].str.contains("total", na=False, case=False)]

# %%
def epf_correct_camelot(df: pd.DataFrame):
    # TODO: find a method to resolve this issue with camelot itself.
    if df.iloc[:, 0].str.match(r'([\s\w]+)(\d+) (\d[\d,.]*)$').any():
        df.iloc[7, [0,1]] = df.iloc[:, 0].str.extract(r'(.*) (\d[\d,.]*)$').iloc[7]
        df.iloc[2, [0,1]] = df.iloc[:, 1].str.extract(r'(.*) (\d[\d,.]*)$').iloc[2]
    return df

# %%
def prep_row_labels(df: pd.DataFrame, lheads=["head", "gender"]):
    headings = df.iloc[:, 0].str.replace(r"(\d{2})(\d{2})", r"\1-\2", regex=True)
    headings[0:len(lheads)] = lheads
    headings = headings.str.lower()
    return df.rename(index=headings).drop(0, axis=1)

# %%
def reshape_epf(df: pd.DataFrame, id_vars=["head", "gender"]):
    df.iloc[0] = df.iloc[0].str.replace("\n", "").replace("", np.nan).ffill()
    df = df.T.melt(id_vars=id_vars, var_name="age")
    categorical_columns = id_vars + ["age"]
    df[categorical_columns] = df[categorical_columns].astype("category")
    # TODO: convert values to integer values
    # df.value = pd.to_numeric(df.value.str.replace(",", "").str.strip(), errors="coerce", downcast="unsigned")
    return df

# %%
def display_df(df: pd.DataFrame):
    display(df)
    return df

# %%
monthly_epf_tables[0].pipe(strip_month_headline).pipe(exclude_totals_row).pipe(display_df).pipe(epf_correct_camelot).pipe(prep_row_labels).pipe(display_df).pipe(reshape_epf)
# Out:
#                       0                                               1   \
# 0                    Age  Number of new EPF subscribers during the month
# 1                    NaN                                            Male
# 2                    NaN                              Less than 18 6,475
# 3                   1821                                        2,12,534
# 4                   2225                                        1,96,747
# 5                   2628                                          85,285
# 6                   2935                                        1,21,667
# 7  More than 35 1,50,424                                             NaN
#
#        2       3              4         5   \
# 0     NaN     NaN            NaN       NaN
# 1  Female  Others  Not Available     Total
# 2   1,358     NaN            NaN     7,833
# 3  55,263     NaN              3  2,67,800
# 4  78,152       1              4  2,74,904
# 5  32,066       1              4  1,17,356
# 6  56,418       1              4  1,78,090
# 7  63,300       4             13  2,13,741
#
#                                                   6       7       8   \
# 0  Number of members that ceased subscribing duri...     NaN     NaN
# 1                                               Male  Female  Others
# 2                                              1,216     659     NaN
# 3                                           1,20,147  28,271       1
# 4                                           2,49,681  71,402       3
# 5                                           1,78,061  46,293       3
# 6                                           2,75,107  70,516       3
# 7                                           2,58,615  77,029       2
#
#               9         10                                                 11  \
# 0            NaN       NaN  Number of exited members who rejoined and resu...
# 1  Not Available     Total                                               Male
# 2            NaN     1,875                                                468
# 3              1  1,48,420                                           1,01,355
# 4              3  3,21,089                                           2,93,409
# 5              8  2,24,365                                           2,22,038
# 6             61  3,45,687                                           3,43,358
# 7             93  3,35,739                                           3,10,385
#
#        12      13             14        15
# 0     NaN     NaN            NaN       NaN
# 1  Female  Others  Not Available     Total
# 2     257     NaN            NaN       725
# 3  19,997     NaN            NaN  1,21,352
# 4  64,732       4            NaN  3,58,145
# 5  46,113       8            NaN  2,68,159
# 6  72,223       6            NaN  4,15,587
# 7  73,044       3              1  3,83,433
#                                                           1       2       3   \
# head          Number of new EPF subscribers during the month     NaN     NaN
# gender                                                  Male  Female  Others
# less than 18                                           6,475   1,358     NaN
# 18-21                                               2,12,534  55,263     NaN
# 22-25                                               1,96,747  78,152       1
# 26-28                                                 85,285  32,066       1
# 29-35                                               1,21,667  56,418       1
# more than 35                                        1,50,424  63,300       4
#
#                          4         5   \
# head                    NaN       NaN
# gender        Not Available     Total
# less than 18            NaN     7,833
# 18-21                     3  2,67,800
# 22-25                     4  2,74,904
# 26-28                     4  1,17,356
# 29-35                     4  1,78,090
# more than 35             13  2,13,741
#
#                                                              6       7   \
# head          Number of members that ceased subscribing duri...     NaN
# gender                                                     Male  Female
# less than 18                                              1,216     659
# 18-21                                                  1,20,147  28,271
# 22-25                                                  2,49,681  71,402
# 26-28                                                  1,78,061  46,293
# 29-35                                                  2,75,107  70,516
# more than 35                                           2,58,615  77,029
#
#                   8              9         10  \
# head             NaN            NaN       NaN
# gender        Others  Not Available     Total
# less than 18     NaN            NaN     1,875
# 18-21              1              1  1,48,420
# 22-25              3              3  3,21,089
# 26-28              3              8  2,24,365
# 29-35              3             61  3,45,687
# more than 35       2             93  3,35,739
#
#                                                              11      12  \
# head          Number of exited members who rejoined and resu...     NaN
# gender                                                     Male  Female
# less than 18                                                468     257
# 18-21                                                  1,01,355  19,997
# 22-25                                                  2,93,409  64,732
# 26-28                                                  2,22,038  46,113
# 29-35                                                  3,43,358  72,223
# more than 35                                           3,10,385  73,044
#
#                   13             14        15
# head             NaN            NaN       NaN
# gender        Others  Not Available     Total
# less than 18     NaN            NaN       725
# 18-21            NaN            NaN  1,21,352
# 22-25              4            NaN  3,58,145
# 26-28              8            NaN  2,68,159
# 29-35              6            NaN  4,15,587
# more than 35       3              1  3,83,433
#                                                  head         gender  \
# 0      Number of new EPF subscribers during the month           Male
# 1      Number of new EPF subscribers during the month         Female
# 2      Number of new EPF subscribers during the month         Others
# 3      Number of new EPF subscribers during the month  Not Available
# 4      Number of new EPF subscribers during the month          Total
# ..                                                ...            ...
# 85  Number of exited members who rejoined and resu...           Male
# 86  Number of exited members who rejoined and resu...         Female
# 87  Number of exited members who rejoined and resu...         Others
# 88  Number of exited members who rejoined and resu...  Not Available
# 89  Number of exited members who rejoined and resu...          Total
#
#              age     value
# 0   less than 18     6,475
# 1   less than 18     1,358
# 2   less than 18       NaN
# 3   less than 18       NaN
# 4   less than 18     7,833
# ..           ...       ...
# 85  more than 35  3,10,385
# 86  more than 35    73,044
# 87  more than 35         3
# 88  more than 35         1
# 89  more than 35  3,83,433
#
# [90 rows x 4 columns]

# %%
parse_date_head(monthly_epf_tables[0]).iloc[0]
# Out:
# Timestamp('2022-04-01 00:00:00')

# %%
def epf_data_pipeline(df: pd.DataFrame):
    month = parse_date_head(df).iloc[0]
    df = df.pipe(strip_month_headline) \
        .pipe(exclude_totals_row) \
        .pipe(epf_correct_camelot) \
        .pipe(prep_row_labels) \
        .pipe(reshape_epf)
    df["year"] = month.year
    df["month"] = month.month
    df["sector"] = np.nan
    return df

# %%
fnl_epf = pd.concat(map(epf_data_pipeline, monthly_epf_tables))

# %%
def is_esic(df: pd.DataFrame):
    return df.iloc[:, 5].str.lower().str.contains('Number of newly registered', na=False, case=False).any()

# %%
monthly_esic_tables = list(filter(is_monthly, filter(is_esic, tables)))

# %%
monthly_esic_tables[0].pipe(strip_month_headline).pipe(exclude_totals_row).pipe(prep_row_labels).pipe(display_df).pipe(reshape_epf).head()
# Out:
#                                                               1          2  \
# head          Number of existing employees who paid during \...
# gender                                                     Male     Female
# less than 18                                              4,483      2,803
# 18-21                                                  9,18,773   1,98,623
# 22-25                                                 35,44,932   8,85,911
# 26-28                                                 30,93,386   6,01,837
# 29-35                                                 57,44,816  11,63,983
# more than 35                                          82,45,820  24,31,948
#
#                    3            4  \
# head
# gender        Others        Total
# less than 18                7,286
# 18-21             35    11,17,431
# 22-25            117    44,30,960
# 26-28            104    36,95,327
# 29-35            196    69,08,995
# more than 35     451  1,06,78,219
#
#                                                               5       6  \
# head          Number of newly registered employees & \npayin...
# gender                                                     Male  Female
# less than 18                                              1,445     491
# 18-21                                                  2,07,870  38,307
# 22-25                                                  3,02,642  71,113
# 26-28                                                  1,56,863  31,401
# 29-35                                                  1,94,401  51,892
# more than 35                                           1,77,240  55,942
#
#                    7         8
# head
# gender        Others     Total
# less than 18             1,936
# 18-21              7  2,46,184
# 22-25             10  3,73,765
# 26-28              7  1,88,271
# 29-35              8  2,46,301
# more than 35      13  2,33,195
#                                                 head  gender           age  \
# 0  Number of existing employees who paid during t...    Male  less than 18
# 1  Number of existing employees who paid during t...  Female  less than 18
# 2  Number of existing employees who paid during t...  Others  less than 18
# 3  Number of existing employees who paid during t...   Total  less than 18
# 4  Number of newly registered employees & paying ...    Male  less than 18
#
#    value
# 0  4,483
# 1  2,803
# 2
# 3  7,286
# 4  1,445

# %%
def esic_data_pipeline(df: pd.DataFrame):
    month = parse_date_head(df).iloc[0]
    df = df.pipe(strip_month_headline) \
        .pipe(exclude_totals_row) \
        .pipe(prep_row_labels) \
        .pipe(reshape_epf)
    df["year"] = month.year
    df["month"] = month.month
    df["sector"] = np.nan
    return df

# %%
fnl_esic = pd.concat(map(esic_data_pipeline, monthly_esic_tables))

# %%
fnl_esic
# Out:
#                                                  head  gender           age  \
# 0   Number of existing employees who paid during t...    Male  less than 18
# 1   Number of existing employees who paid during t...  Female  less than 18
# 2   Number of existing employees who paid during t...  Others  less than 18
# 3   Number of existing employees who paid during t...   Total  less than 18
# 4   Number of newly registered employees & paying ...    Male  less than 18
# ..                                                ...     ...           ...
# 43  Number of existing employees who paid during t...   Total  more than 35
# 44  Number of newly registered employees & paying ...    Male  more than 35
# 45  Number of newly registered employees & paying ...  Female  more than 35
# 46  Number of newly registered employees & paying ...  Others  more than 35
# 47  Number of newly registered employees & paying ...   Total  more than 35
#
#           value  year  month  sector
# 0         4,483  2022      4     NaN
# 1         2,803  2022      4     NaN
# 2                2022      4     NaN
# 3         7,286  2022      4     NaN
# 4         1,445  2022      4     NaN
# ..          ...   ...    ...     ...
# 43  1,05,64,641  2022     12     NaN
# 44     2,01,668  2022     12     NaN
# 45       68,303  2022     12     NaN
# 46            8  2022     12     NaN
# 47     2,69,979  2022     12     NaN
#
# [432 rows x 7 columns]

# %%
def is_nps(df: pd.DataFrame):
    return df.iloc[:, 1].str.lower().str.replace("\n", "").str.contains('existing subscribers', na=False,case=False).any()

# %%
monthly_nps_tables = list(filter(is_monthly, filter(is_nps, tables)))

# %%
from functools import partial
prep_nps_row_labels = partial(prep_row_labels, lheads=["head", "sector", "gender"])
# reshape_nps = partial(reshape_epf, id_vars=["head", "gender", "sector"])

# %%
def reshape_nps(df: pd.DataFrame, id_vars=["head", "gender", "sector"]):
    df = df.T.replace("", np.nan).ffill()
    df = df.melt(id_vars=id_vars, var_name="age")
    categorical_columns = id_vars + ["age"]
    df[categorical_columns] = df[categorical_columns].astype("category")
    return df

# %%
monthly_nps_tables[0].pipe(strip_month_headline).pipe(exclude_totals_row).pipe(prep_nps_row_labels).pipe(display_df).pipe(reshape_nps)
# Out:
#                                                         1   \
# head     Total Existing \nSubscribers \ncontributing \n...
# sector
# gender
# 18-21                                               12,538
# 22-25                                             2,34,188
# 26-28                                             5,11,356
# 29-35                                            21,21,014
# > 35                                             30,96,941
# non-ira                                              1,830
#
#                                                     2       3            4   \
# head     New Subscribers contributing during the month
# sector                                    Central Govt
# gender                                            Male  Female  Transgender
# 18-21                                              394      66            -
# 22-25                                            3,309     621            -
# 26-28                                            3,427     542            -
# 29-35                                            2,350     479            -
# > 35                                               696     272            -
# non-ira                                              -       -            -
#
#                 5                  6           7       8            9   \
# head
# sector                                 State Govt
# gender   Non-\nIRA              Total        Male  Female  Transgender
# 18-21               -             460         371      93            -
# 22-25                 -         3,930       1,819     818            -
# 26-28                 -         3,969       2,712   1,508            -
# 29-35                 -         2,829       6,085   4,332            -
# > 35                -             968       6,794   4,574            -
# non-ira          -                  -           -       -
#
#                           10                   11  \
# head
# sector
# gender               Non-IRA                Total
# 18-21                         -               464
# 22-25                          -            2,637
# 26-28                          -            4,220
# 29-35                            -         10,417
# > 35                             -         11,368
# non-ira  -                 1                    1
#
#                                   12      13           14       15  \
# head
# sector   Non-Govt (Corporate Sector)
# gender                          Male  Female  Transgender  Non-IRA
# 18-21                             79      35            -
# 22-25                          2,319   1,152            -
# 26-28                          2,647   1,075            -
# 29-35                          5,570   1,418            1
# > 35                           7,780   1,230            -
# non-ira                            -       -            -        -
#
#                          16                                     17
# head
# sector                                     Total New \nSubscribers
# gender                Total
# 18-21    -              114                                  1,038
# 22-25      -          3,471                                 10,038
# 26-28      -          3,722                                 11,911
# 29-35      -          6,989                                 20,235
# > 35       -          9,010                                 21,346
# non-ira                      -                                   1
#                                                   head       gender  \
# 0    Total Existing \nSubscribers \ncontributing \n...          NaN
# 1        New Subscribers contributing during the month         Male
# 2        New Subscribers contributing during the month       Female
# 3        New Subscribers contributing during the month  Transgender
# 4        New Subscribers contributing during the month    Non-\nIRA
# ..                                                 ...          ...
# 97       New Subscribers contributing during the month       Female
# 98       New Subscribers contributing during the month  Transgender
# 99       New Subscribers contributing during the month      Non-IRA
# 100      New Subscribers contributing during the month        Total
# 101      New Subscribers contributing during the month        Total
#
#                           sector      age  \
# 0                            NaN    18-21
# 1                   Central Govt    18-21
# 2                   Central Govt    18-21
# 3                   Central Govt    18-21
# 4                   Central Govt    18-21
# ..                           ...      ...
# 97   Non-Govt (Corporate Sector)  non-ira
# 98   Non-Govt (Corporate Sector)  non-ira
# 99   Non-Govt (Corporate Sector)  non-ira
# 100  Non-Govt (Corporate Sector)  non-ira
# 101      Total New \nSubscribers  non-ira
#
#                                      value
# 0                                   12,538
# 1                                      394
# 2                                       66
# 3                                        -
# 4                                        -
# ..                                     ...
# 97                                       -
# 98                                       -
# 99                                       -
# 100                                      -
# 101  -                                   1
#
# [102 rows x 5 columns]

# %%
def nps_data_pipeline(df: pd.DataFrame):
    month = parse_date_head(df).iloc[0]
    df = df.pipe(strip_month_headline) \
        .pipe(exclude_totals_row) \
        .pipe(prep_nps_row_labels) \
        .pipe(reshape_nps)
    df["year"] = month.year
    df["month"] = month.month
    for col in ["head", 'gender', 'sector']:
        df[col] = df[col].str.replace("\n", "")
    df["age"] = df["age"].str.replace("> 35", "more than 35")
    return df

# %%
fnl_nps = pd.concat(map(nps_data_pipeline, monthly_nps_tables))

# %%
fnl_nps
# Out:
#                                                   head       gender  \
# 0    Total Existing Subscribers contributing during...          NaN
# 1        New Subscribers contributing during the month         Male
# 2        New Subscribers contributing during the month       Female
# 3        New Subscribers contributing during the month  Transgender
# 4        New Subscribers contributing during the month      Non-IRA
# ..                                                 ...          ...
# 97       New Subscribers contributing during the month       Female
# 98       New Subscribers contributing during the month  Transgender
# 99       New Subscribers contributing during the month      Non-IRA
# 100      New Subscribers contributing during the month        Total
# 101      New Subscribers contributing during the month        Total
#
#                           sector      age  \
# 0                            NaN    18-21
# 1                   Central Govt    18-21
# 2                   Central Govt    18-21
# 3                   Central Govt    18-21
# 4                   Central Govt    18-21
# ..                           ...      ...
# 97   Non-Govt (Corporate Sector)  non-ira
# 98   Non-Govt (Corporate Sector)  non-ira
# 99   Non-Govt (Corporate Sector)  non-ira
# 100  Non-Govt (Corporate Sector)  non-ira
# 101        Total New Subscribers  non-ira
#
#                                      value  year  month
# 0                                   12,538  2022      4
# 1                                      394  2022      4
# 2                                       66  2022      4
# 3                                        -  2022      4
# 4                                        -  2022      4
# ..                                     ...   ...    ...
# 97                                       -  2022     12
# 98                                       -  2022     12
# 99                                       -  2022     12
# 100                                      -  2022     12
# 101  -                                   1  2022     12
#
# [918 rows x 7 columns]

# %%
fnl_df = pd.concat([fnl_nps, fnl_epf, fnl_esic])

# %%
interim_path = Path.cwd().parent / "data" / "interim" / f"{src_pdf_filename}.csv"
fnl_df.to_csv(interim_path, index=False)
