# %%
import pandas as pd
from pathlib import Path
import re

# %%
files = list(Path("../data/raw/ub_macro").glob("*.xlsx"))

# %%
xls = [pd.read_excel(f).dropna(axis=1, how="all").dropna(axis=0, how="all") for f in files]

# %%
for file, df in zip(files, xls):
    print(file.stem)
    display(df.head())
# Out:
# union-budget-2018-2019
#            Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 1  Budget at a Glance           NaN        NaN        NaN        NaN
# 3                 NaN  (In ` crore)        NaN        NaN        NaN
# 5                 NaN           NaN        NaN  2016-2017  2017-2018
# 6                 NaN           NaN        NaN    Actuals     Budget
# 7                 NaN           NaN        NaN        NaN  Estimates
#
#   Unnamed: 5 Unnamed: 6
# 1        NaN        NaN
# 3        NaN        NaN
# 5  2017-2018  2018-2019
# 6    Revised     Budget
# 7  Estimates  Estimates
# union-budget-2019-2020
#         बजट का सार Budget at a Glance                          Unnamed: 2  \
# 0             (₹ करोड़) (In ₹ crores)                                 NaN
# 1                                 NaN                                 NaN
# 2              1. राजस्व प्राप्तियां                  1. Revenue Receipts
# 3      2. कर राजस्व (केंद्र को निवल )      2. Tax Revenue (Net to Centre)
# 4                 3. कर भिन्न राजस्व                   3. Non Tax Revenue
#
#                         Unnamed: 3  \
# 0                              NaN
# 1  2017-2018\n वास्तविक\n\nActuals
# 2                          1435233
# 3                          1242488
# 4                           192745
#
#                                    Unnamed: 4  \
# 0                                         NaN
# 1  2018-2019\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     1725738
# 3                                     1480649
# 4                                      245089
#
#                                         Unnamed: 5  \
# 0                                              NaN
# 1  2018-2019\nसंशोधित\nअनुमान\nRevised \nEstimates
# 2                                          1729682
# 3                                          1484406
# 4                                           245276
#
#                                    Unnamed: 6
# 0                                         NaN
# 1  2019-2020\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     1962761
# 3                                     1649582
# 4                                      313179
# union-budget-2020-2021
#         बजट का सार Budget at a Glance                          Unnamed: 2  \
# 0             (₹ करोड़) (In ₹ crores)                                 NaN
# 1                                 NaN                                 NaN
# 2              1. राजस्व प्राप्तियां                  1. Revenue Receipts
# 3      2. कर राजस्व (केंद्र को निवल )      2. Tax Revenue (Net to Centre)
# 4                 3. कर भिन्न राजस्व                   3. Non Tax Revenue
#
#                         Unnamed: 3  \
# 0                              NaN
# 1  2018-2019\n वास्तविक\n\nActuals
# 2                          1552916
# 3                          1317211
# 4                           235705
#
#                                    Unnamed: 4  \
# 0                                         NaN
# 1  2019-2020\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     1962761
# 3                                     1649582
# 4                                      313179
#
#                                         Unnamed: 5  \
# 0                                              NaN
# 1  2019-2020\nसंशोधित\nअनुमान\nRevised \nEstimates
# 2                                          1850101
# 3                                          1504587
# 4                                           345514
#
#                                    Unnamed: 6
# 0                                         NaN
# 1  2020-2021\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     2020926
# 3                                     1635909
# 4                                      385017
# union-budget-2021-2022
#         बजट का सार Budget at a Glance                          Unnamed: 2  \
# 0             (₹ करोड़) (In ₹ crores)                                 NaN
# 1                                 NaN                                 NaN
# 2              1. राजस्व प्राप्तियां                  1. Revenue Receipts
# 3      2. कर राजस्व (केंद्र को निवल )      2. Tax Revenue (Net to Centre)
# 4                 3. कर भिन्न राजस्व                   3. Non Tax Revenue
#
#                         Unnamed: 3  \
# 0                              NaN
# 1  2019-2020\n वास्तविक\n\nActuals
# 2                          1684059
# 3                          1356902
# 4                           327157
#
#                                    Unnamed: 4  \
# 0                                         NaN
# 1  2020-2021\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     2020926
# 3                                     1635909
# 4                                      385017
#
#                                         Unnamed: 5  \
# 0                                              NaN
# 1  2020-2021\nसंशोधित\nअनुमान\nRevised \nEstimates
# 2                                          1555153
# 3                                          1344501
# 4                                           210652
#
#                                    Unnamed: 6
# 0                                         NaN
# 1  2021-2022\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     1788424
# 3                                     1545396
# 4                                      243028
# union-budget-2022-2023
#         बजट का सार Budget at a Glance                          Unnamed: 2  \
# 0             (₹ करोड़) (In ₹ crores)                                 NaN
# 1                                 NaN                                 NaN
# 2              1. राजस्व प्राप्तियां                  1. Revenue Receipts
# 3      2. कर राजस्व (केंद्र को निवल )      2. Tax Revenue (Net to Centre)
# 4                 3. कर भिन्न राजस्व                   3. Non Tax Revenue
#
#                         Unnamed: 3  \
# 0                              NaN
# 1  2020-2021\n वास्तविक\n\nActuals
# 2                          1633920
# 3                          1426287
# 4                           207633
#
#                                    Unnamed: 4  \
# 0                                         NaN
# 1  2021-2022\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     1788424
# 3                                     1545396
# 4                                      243028
#
#                                         Unnamed: 5  \
# 0                                              NaN
# 1  2021-2022\nसंशोधित\nअनुमान\nRevised \nEstimates
# 2                                          2078936
# 3                                          1765145
# 4                                           313791
#
#                                    Unnamed: 6
# 0                                         NaN
# 1  2022-2023\nबजट\nअनुमान\nBudget \nEstimates
# 2                                     2204422
# 3                                     1934771
# 4                                      269651

# %% [markdown]
# The format of data in the union budget of 2018-19 is disimilar from the rest of the target years. It will need additional transformation steps.

# %%
for df in xls[1:]:
    print(df.shape)
# Out:
# (26, 6)
# (26, 6)
# (25, 6)
# (25, 6)

# %%
def extract_rows_with_data_points(df: pd.DataFrame):
    index = df.iloc[:,2:].dropna(how='all').index
    return df.iloc[index].reset_index(drop=True)

# %%
for df in xls[1:]:
    print(extract_rows_with_data_points(df).shape)
# Out:
# (18, 6)
# (18, 6)
# (18, 6)
# (19, 6)

# %%
def assign_column_names(df: pd.DataFrame):
    df.columns = ["hindi_head", "english_head"] + df.iloc[0, 2:].to_list()
    return df.iloc[1:].reset_index(drop=True)

# %%
pipe(extract_rows_with_data_points).pipe(assign_column_names).drop(columns="hindi_head")

# %%
def remove_utf8(text):
    if isinstance(text, str):
        # Use regular expression to remove non-UTF-8 characters
        return ''.join(char for char in text if char.isascii())
    else:
        return text  # Return non-string values as is

# %%
def remove_newlines(text):
    if isinstance(text, str):
        # Replace "\n" with an empty string
        return text.replace("\n", "")
    else:
        return text  # Return non-string values as is

# %%
def remove_brackets(text):
    if isinstance(text, str):
        # Use regular expression to remove content within both parentheses and square brackets
        return re.sub(r'\([^)]*\)|\[[^\]]*\]', '', text)
    else:
        return text  # Return non-string values as is

# %%
def data_cleaning_pipeline(df: pd.DataFrame):
    return df.pipe(extract_rows_with_data_points) \
        .map(remove_newlines).map(remove_brackets) \
        .map(remove_utf8).pipe(assign_column_names) \
        .drop(columns="hindi_head")

# %%
def split_variable_column(df: pd.DataFrame, column_name: str = "variable"):
    df['year'] = df[column_name].str.extract(r'(\d{4}-\d{4})')
    df['estimate_type'] = df[column_name].str.replace(r'\d{4}-\d{4}', '', regex=True).str.strip()

    return df.drop(columns=column_name)

# %%
cln_dfs = map(lambda df: df.pipe(data_cleaning_pipeline).melt(id_vars="english_head").pipe(split_variable_column), xls[1:])
df = pd.concat(cln_dfs)

# %%
col_order = ["year", "estimate_type", "english_head", "value"]
df["english_head"] = df["english_head"].str.strip()
fnl_df = df[col_order]
fnl_df.sample(10)
# Out:
#          year      estimate_type                         english_head    value
# 15  2018-2019            Actuals                   16. Fiscal Deficit   649418
# 34  2018-2019  Revised Estimates                  1. Revenue Receipts  1729682
# 10  2020-2021            Actuals                11. Interest Payments   679869
# 5   2017-2018            Actuals                    6. Other Receipts   100045
# 28  2019-2020   Budget Estimates       12. Grants in Aid for creation   207333
# 46  2019-2020  Revised Estimates               13. On Capital Account   348907
# 25  2018-2019   Budget Estimates                 9. Total Expenditure  2442213
# 28  2021-2022   Budget Estimates                11. Interest Payments   809701
# 29  2019-2020   Budget Estimates               13. On Capital Account   338569
# 23  2019-2020   Budget Estimates  7. Borrowings and Other Liabilities   703760

# %%
fnl_df.to_csv("../data/interim/ub_macro_last_4_years.csv", index=False)
